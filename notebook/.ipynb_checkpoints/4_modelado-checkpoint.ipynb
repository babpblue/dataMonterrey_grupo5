# %%
# %matplotlib inline
import pandas as pd

# %%
compras_df = pd.read_csv('../data/clean_compras.csv')

# %%
data = compras_df##.copy()

# %%
data.dtypes
# Out:
# PROV              int64
# BENEFICIARIO     object
# RFC              object
# NUM FACT         object
# CONTRATO         object
# DESCRIPCION      object
# TIPO OP          object
# BCO-OP          float64
# FECH EMI         object
# IMPORTE         float64
# SHEET            object
# dtype: object

# %% [markdown]
# ## Llenar los valores faltantes del dataframe

# %%
for i, column in enumerate(list([str(d) for d in data.dtypes])):
    #si el tipo de dato es object
    if column == "object":
        data[data.columns[i]]= data[data.columns[i]].fillna(data[data.columns[i]].mode())
        data[data.columns[i]]= data[data.columns[i]].astype("category").cat.codes
    else:
        data[data.columns[i]]= data[data.columns[i]].fillna(data[data.columns[i]].median())

# %%
data.dtypes
# Out:
# PROV              int64
# BENEFICIARIO      int16
# RFC               int16
# NUM FACT          int16
# CONTRATO          int16
# DESCRIPCION       int16
# TIPO OP            int8
# BCO-OP          float64
# FECH EMI          int16
# IMPORTE         float64
# SHEET              int8
# dtype: object

# %%
data.head(5)
# Out:
#      PROV  BENEFICIARIO   RFC  NUM FACT  CONTRATO  DESCRIPCION  TIPO OP  \
# 0  123629          1665  1623     14775      4788         3208        1
# 1  123629          1665  1623     14776      4788         3206        1
# 2  123629          1665  1623     14777      4788         3207        1
# 3  123629          1665  1623     14778      4788         3168        1
# 4  123629          1665  1623     14779      4788         3147        1
#
#         BCO-OP  FECH EMI     IMPORTE  SHEET
# 0  225000024.0         9  7859725.14      1
# 1  225000024.0         9  3152852.45      1
# 2  225000024.0         9  8763325.29      1
# 3  229000030.0         9  1842839.12      1
# 4  239000001.0         9  2281374.75      1

# %% [markdown]
# ### Utilizar random forest (MODELO SUPERVISADO)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import train_test_split

# %%
y = data.pop('IMPORTE')

# %%
X = data

# %%
X
# Out:
#          PROV  BENEFICIARIO   RFC  NUM FACT  CONTRATO  DESCRIPCION  TIPO OP  \
# 0      123629          1665  1623     14775      4788         3208        1
# 1      123629          1665  1623     14776      4788         3206        1
# 2      123629          1665  1623     14777      4788         3207        1
# 3      123629          1665  1623     14778      4788         3168        1
# 4      123629          1665  1623     14779      4788         3147        1
# ...       ...           ...   ...       ...       ...          ...      ...
# 17637  203016          2341   544     11441       303         8487        0
# 17638  203016          2341   544     11445       303         8487        0
# 17639  203016          2392  2331      4291       303        10171        0
# 17640  203016          2413  2345      8231       303         8242        0
# 17641  203016          2436  2370       105       303         8371        0
#
#             BCO-OP  FECH EMI  SHEET
# 0      225000024.0         9      1
# 1      225000024.0         9      1
# 2      225000024.0         9      1
# 3      229000030.0         9      1
# 4      239000001.0         9      1
# ...            ...       ...    ...
# 17637    1097438.0       234      3
# 17638    1097440.0       234      3
# 17639  245000001.0       237      3
# 17640    1097471.0       236      3
# 17641    1097327.0       224      3
#
# [17642 rows x 10 columns]

# %% [markdown]
# ## Dividir los datos en dos grupos

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
clf = RandomForestRegressor(n_estimators=1000, max_depth = 4)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=4, n_estimators=1000)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, clf.predict(X_test))
# Out:
# 0.20778272825707766

# %% [markdown]
# ## MODELO NO SUPERVISADO O DE CLUSTERING

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="sklearn")
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
compras_df_c = compras_df.copy()

# %%
compras_df_c.head()
# Out:
#      PROV                                       BENEFICIARIO           RFC  \
# 0  123629  PAVIMENTACIONES, CAMINOS Y COMPACTACIONES, S.A...  PCC890216TG1
# 1  123629  PAVIMENTACIONES, CAMINOS Y COMPACTACIONES, S.A...  PCC890216TG1
# 2  123629  PAVIMENTACIONES, CAMINOS Y COMPACTACIONES, S.A...  PCC890216TG1
# 3  123629  PAVIMENTACIONES, CAMINOS Y COMPACTACIONES, S.A...  PCC890216TG1
# 4  123629  PAVIMENTACIONES, CAMINOS Y COMPACTACIONES, S.A...  PCC890216TG1
#
#   NUM FACT      CONTRATO                                        DESCRIPCION  \
# 0    B4668  SOP/697/2016  EJE RP-2016 (GONZALITOS) EST. 18E OP-R23-01/16...
# 1    B4669  SOP/697/2016  EJE RP-2016 (AV. ALMAZAN, AV. AARON SAENZ Y AV...
# 2    B4725  SOP/697/2016  EJE RP-2016 (AV. ALMAZAN, AV. AARON SAENZ Y AV...
# 3    B4734  SOP/697/2016  EJE RE-FDO-DES-MCIPAL-2016 (AV. FIDEL VELAZQUE...
# 4    B4735  SOP/697/2016  EJE R23-2016 (PROG-REG) EST. 21E OP-R23-01/16-...
#
#   TIPO OP       BCO-OP             FECH EMI     IMPORTE         SHEET
# 0      TR  225000024.0  2017-01-09 00:00:00  7859725.14  CONTRATISTAS
# 1      TR  225000024.0  2017-01-09 00:00:00  3152852.45  CONTRATISTAS
# 2      TR  225000024.0  2017-01-09 00:00:00  8763325.29  CONTRATISTAS
# 3      TR  229000030.0  2017-01-09 00:00:00  1842839.12  CONTRATISTAS
# 4      TR  239000001.0  2017-01-09 00:00:00  2281374.75  CONTRATISTAS

# %%
compras_df_c_grupo = compras_df_c.groupby("BENEFICIARIO").agg({'CONTRATO': lambda x: x.nunique(), 'IMPORTE': 'sum',
                                                              'NUM FACT': lambda x: x.nunique()})

# %%
compras_df_cluster = compras_df_c_grupo.reset_index()

# %%
compras_df_cluster
# Out:
#                                            BENEFICIARIO  CONTRATO  \
# 0      (F INTERAC) EOLICA SANTA CATARINA, S DE RL DE CV         1
# 1     (F INTERACC) CHRISTUS MUGUERZA SISTEMAS HOSPIT...         2
# 2     (F INTERACC) EOLICA SANTA CATARINA, S. DE R.L....         1
# 3                3G CONSULTING Y ASESORIA, S.A. DE C.V.         8
# 4                               ABA SEGUROS,S.A DE C.V.         2
# ...                                                 ...       ...
# 2454                               ZAYAS CAMACHO MARTIN         1
# 2455                ZERTUCHE HERNANDEZ FRANCISCO JAVIER         1
# 2456                      ZOZAYA HERNANDEZ MONICA LUCIA         1
# 2457                 ZULU INFRAESTRUCTURA, S.A. DE C.V.         2
# 2458                              ZUÑIGA GARCIA OSVALDO         1
#
#           IMPORTE  NUM FACT
# 0     10389165.28         3
# 1     19375726.73       644
# 2     10704726.94         3
# 3      2950822.44         8
# 4     19013345.90        41
# ...           ...       ...
# 2454      9048.71         1
# 2455     10318.64         2
# 2456     76891.46        13
# 2457   4999874.33         4
# 2458     50391.55         1
#
# [2459 rows x 4 columns]

# %%
compras_df_c_grupo_f = compras_df_c_grupo.reset_index().drop(['BENEFICIARIO'], axis = 1)

# %%
normalizado_compras_df = (compras_df_c_grupo_f - compras_df_c_grupo_f.min())/(compras_df_c_grupo_f.max() - compras_df_c_grupo_f.min())

# %%
normalizado_compras_df.head(5)
# Out:
#    CONTRATO   IMPORTE  NUM FACT
# 0  0.000000  0.020468  0.002561
# 1  0.001497  0.038172  0.823303
# 2  0.000000  0.021089  0.002561
# 3  0.010479  0.005813  0.008963
# 4  0.001497  0.037458  0.051216

# %%
wcss=[]

# %%
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, max_iter= 300)
    kmeans.fit(normalizado_compras_df)
    wcss.append(kmeans.inertia_)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:110: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\ProgramData\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 217, in _count_physical_cores
#     raise ValueError(
